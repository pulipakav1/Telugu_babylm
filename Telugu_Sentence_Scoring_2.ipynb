# %%
# %pip install tqdm
# Out:
# Keyring is skipped due to an exception: 'keyring.backends'
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /usr/local/anaconda3/lib/python3.7/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install huggingface_hub
# Out:
# Keyring is skipped due to an exception: 'keyring.backends'
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: huggingface_hub in ./.local/lib/python3.7/site-packages (0.16.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (4.3.0)
# Requirement already satisfied: importlib-metadata in ./.local/lib/python3.7/site-packages (from huggingface_hub) (6.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: fsspec in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (2022.10.0)
# Requirement already satisfied: requests in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (2.28.1)
# Requirement already satisfied: filelock in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (3.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/anaconda3/lib/python3.7/site-packages (from huggingface_hub) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/anaconda3/lib/python3.7/site-packages (from packaging>=20.9->huggingface_hub) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from importlib-metadata->huggingface_hub) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests->huggingface_hub) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests->huggingface_hub) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests->huggingface_hub) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install indic-nlp-library
# Out:
# Keyring is skipped due to an exception: 'keyring.backends'
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: indic-nlp-library in ./.local/lib/python3.7/site-packages (0.92)
# Requirement already satisfied: numpy in /usr/local/anaconda3/lib/python3.7/site-packages (from indic-nlp-library) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/anaconda3/lib/python3.7/site-packages (from indic-nlp-library) (1.3.5)
# Requirement already satisfied: sphinx-rtd-theme in ./.local/lib/python3.7/site-packages (from indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinx-argparse in ./.local/lib/python3.7/site-packages (from indic-nlp-library) (0.4.0)
# Requirement already satisfied: morfessor in ./.local/lib/python3.7/site-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/anaconda3/lib/python3.7/site-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/anaconda3/lib/python3.7/site-packages (from pandas->indic-nlp-library) (2022.1)
# Requirement already satisfied: sphinx>=1.2.0 in ./.local/lib/python3.7/site-packages (from sphinx-argparse->indic-nlp-library) (5.3.0)
# Requirement already satisfied: docutils<0.21 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in ./.local/lib/python3.7/site-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.2)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.28.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.12)
# Requirement already satisfied: Pygments>=2.12 in ./.local/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.17.2)
# Requirement already satisfied: packaging>=21.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (21.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.3)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: importlib-metadata>=4.8 in ./.local/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (6.7.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/anaconda3/lib/python3.7/site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.9.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=4.8->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (4.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=4.8->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/anaconda3/lib/python3.7/site-packages (from Jinja2>=3.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/anaconda3/lib/python3.7/site-packages (from packaging>=21.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2022.9.24)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["HF_TOKEN"] = ""

# %%
import pandas as pd
import numpy as np
import re
from collections import Counter
from tqdm import tqdm
import unicodedata
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory

# %%
df = pd.read_csv("hf://datasets/SuryaKrishna02/aya-telugu-news-articles/news_articles_dataset.csv")

# %%
df_articles = df[df["template_id"] == 1].copy()
df_articles = df_articles.dropna(subset=["targets"])
df_articles.rename(columns={"targets": "sentence"}, inplace=True)
print("Total Telugu articles:", len(df_articles))
df_articles.head()
# Out:
# Total Telugu articles: 233545
#                                                inputs  \
# 2   ఇవ్వబడిన హెడ్లైన్ తో వార్తా కథనాన్ని రాయండి:\n...
# 3   ఇచ్చిన టైటిల్ తో న్యూస్ కథనాన్ని రాయండి:\nఢిల్...
# 5   ఇచ్చిన టైటిల్ తో వార్తా కథనాన్ని వ్రాయండి:\n8న...
# 10  ఇచ్చిన టైటిల్ తో వార్తా కథనాన్ని వ్రాయండి:\nఆగ...
# 11  ఇవ్వబడిన హెడ్లైన్ తో న్యూస్ కథనాన్ని రాయండి:\n...
#
#                                              sentence  template_id  \
# 2   మధ్యప్రదేశ్లో 108 కొత్త కేసులను గుర్తించిన తర్...            1
# 3   దేశంలో తాజాగా భిన్నమైన వాతావరణ పరిస్థితులు కొన...            1
# 5   తిరుచానూరు సమీపంలోని శిల్పారామంలో 8న హోలి సంబర...            1
# 10  దేశవ్యాప్తంగా విమాన సేవలు అందించేందుకు మరో కొత...            1
# 11  బిజెపి నాయకులను ముందస్తుగా అరెస్టు చేసి మహ్మదా...            1
#
#    template_lang
# 2        ['tel']
# 3        ['tel']
# 5        ['tel']
# 10       ['tel']
# 11       ['tel']

# %%
factory = IndicNormalizerFactory()
normalizer = factory.get_normalizer("te")

def normalize_telugu(text):
    return normalizer.normalize(str(text))

# %%
def remove_urls_emails(text):
    text = re.sub(r'http\S+|www\.\S+', '', str(text))
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'<.*?>', '', text)
    return text

# %%
def clean_punctuation(text):
    text = re.sub(r'[!?.]{2,}', '.', str(text))
    text = re.sub(r'–+', '-', text)
    return text

# %%
def remove_symbols(text):
    return re.sub(r'[^\u0C00-\u0C7FA-Za-z0-9\s.,!?;:()\'"-]', '', str(text))

# %%
def is_telugu_sentence_relaxed(text):
    total = len(text)
    tel_chars = len(re.findall(r'[\u0C00-\u0C7F]', str(text)))
    return (tel_chars / total) > 0.4 if total > 0 else False

# %%
def token_length(text):
    return len(re.findall(r'[\u0C00-\u0C7F]+', str(text)))

# %%
df_articles["sentence"] = df_articles["sentence"].apply(normalize_telugu)
df_articles["sentence"] = df_articles["sentence"].apply(remove_urls_emails)
df_articles["sentence"] = df_articles["sentence"].apply(clean_punctuation)
df_articles["sentence"] = df_articles["sentence"].apply(remove_symbols)

# %%
df_articles = df_articles[df_articles["sentence"].apply(is_telugu_sentence_relaxed)]

# %%
df_articles.drop_duplicates(subset=["sentence"], inplace=True)

# %%
df_articles["length"] = df_articles["sentence"].apply(token_length)
df_articles = df_articles[(df_articles["length"] > 2) & (df_articles["length"] < 200)]

# %%
df_articles["sentence"] = df_articles["sentence"].str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
print(len(df_articles))
# Out:
# 214222

# %%
def tokenize_telugu(text):
    return re.findall(r'[\u0C00-\u0C7F]+', str(text))

# %%
def utterance_length(sentence):
    return len(tokenize_telugu(sentence))
def mean_word_length(sentence):
    words = tokenize_telugu(sentence)
    return np.mean([len(w) for w in words]) if words else 0

# %%
word_freq = Counter()
for s in tqdm(df_articles["sentence"]):
    word_freq.update(tokenize_telugu(s))
print("\nUnique words:", len(word_freq))
def average_freq(sentence, freq_dict):
    words = tokenize_telugu(sentence)
    if not words:
        return 0
    return np.mean([freq_dict[w] for w in words if w in freq_dict])
# Out:
# 100%|██████████| 214222/214222 [00:06<00:00, 33888.92it/s]
# Unique words: 616554

# %%
def get_frames(sentence_list):
    frames = []
    for s in sentence_list:
        words = tokenize_telugu(s)
        frame = ' '.join(words[:3]) if len(words) >= 3 else ' '.join(words)
        frames.append(frame)
    return dict(Counter(frames))

def frame_freq(sentence, frame_dict):
    words = tokenize_telugu(sentence)
    frame = ' '.join(words[:3]) if len(words) >= 3 else ' '.join(words)
    return frame_dict.get(frame, 0)

# %%
frame_dict = get_frames(df_articles["sentence"])
scores = []

for s in tqdm(df_articles["sentence"]):
    frame_frequency = frame_freq(s, frame_dict)
    utt_length = utterance_length(s)
    mean_length = mean_word_length(s)
    mean_freq = average_freq(s, word_freq)
    scores.append({
        "sentence": s,
        "frame_freq": frame_frequency,
        "utterance_length": utt_length,
        "mean_word_length": mean_length,
        "mean_word_freq": mean_freq
    })

df_scores = pd.DataFrame(scores)
print(df_scores.shape)
# Out:
# 100%|██████████| 214222/214222 [00:26<00:00, 8032.22it/s]
# (214222, 5)

# %%
df_scores["frame_rank"] = df_scores["frame_freq"].rank(ascending=False)
df_scores["utterance_rank"] = df_scores["utterance_length"].rank(ascending=True)
df_scores["mean_length_rank"] = df_scores["mean_word_length"].rank(ascending=True)
df_scores["mean_freq_rank"] = df_scores["mean_word_freq"].rank(ascending=False)
df_scores["final_rank"] = (
    df_scores["frame_rank"] +
    df_scores["utterance_rank"] +
    df_scores["mean_length_rank"] +
    df_scores["mean_freq_rank"]
)
ordered_df = df_scores.sort_values(by="final_rank")
ordered_df.reset_index(drop=True, inplace=True)

# %%
import os
print(os.getcwd())
# Out:
# /nfs/storage1/home/pulipakv

# %%
ordered_df["sentence"].to_csv("telugu_curriculum.txt", index=False, header=False, encoding="utf-8")
print("Saved 'telugu_curriculum.txt'")
# Out:
# Saved 'telugu_curriculum.txt'

# %%
token_pattern = re.compile(r'[\u0C00-\u0C7F]+')
sentence_count = 0
token_count = 0

with open("telugu_curriculum.txt", "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        sentence_count += 1
        tokens = token_pattern.findall(line)
        token_count += len(tokens)

# %%
print(f"Total Sentences : {sentence_count:,}")
print(f"Total Tokens : {token_count:,}")
# Out:
# Total Sentences : 214,222
# Total Tokens : 17,015,797

# %%
print("Easy Sentences:")
print(ordered_df["sentence"].head(5))
# Out:
# Easy Sentences:
# 0    తెలంగాణ సీఎం కేసీఆర్ కు అరుదైన ఆహ్వానం అందింది...
# 1    దేశంలో కరోనా కేసులు 15 వేల కన్నా తక్కువే నమోదయ...
# 2    ఏపీ సీఎం జగన్ పశ్చిమ గోదావరి జిల్లా పర్యటన వాయ...
# 3    ఈ నెల 17న తెలంగాణ రాష్ట్ర బంద్కు బీసీ సంఘం నేత...
# 4    భారత్ లో కరోనా కేసులు పెరుగుతున్నాయి. దేశంలో క...
# Name: sentence, dtype: object

# %%
token_pattern = re.compile(r'[\u0C00-\u0C7F]+')
TARGET_TOKENS = 17_000_000   # 17M tokens
output_file = "telugu_17M_tokens.txt"
total_tokens = 0
saved_sentences = 0

with open(output_file, "w", encoding="utf-8") as out:
    for sentence in tqdm(ordered_df["sentence"], desc="Saving 17M tokens"):

        # tokenize using your exact Telugu-token regex
        tokens = token_pattern.findall(sentence)
        if len(tokens) == 0:
            continue

        # if adding this sentence crosses 17M → stop
        if total_tokens + len(tokens) > TARGET_TOKENS:
            break

        # write sentence
        out.write(sentence.strip() + "\n")

        total_tokens += len(tokens)
        saved_sentences += 1
# Out:
# Saving 17M tokens: 100%|█████████▉| 214128/214222 [00:04<00:00, 45128.57it/s]

# %%
print(f"Saved sentences : {saved_sentences:,}")
print(f"Saved tokens    : {total_tokens:,}")
print(f"Output file     : {output_file}")
# Out:
# Saved sentences : 214,128
# Saved tokens    : 16,999,956
# Output file     : telugu_17M_tokens.txt
